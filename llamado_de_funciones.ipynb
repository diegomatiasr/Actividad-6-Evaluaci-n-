# %% [markdown]
# ## Actividad 6 (Evaluación)

# %% [markdown]
# **Diego Matias Rossano | A01737509**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import funciones as fun

# %%
# Agregar y cargar archivo del país
df = pd.read_csv('Sicily.csv')

# %%
# Función para cargar un archivo como un dataframe

def cargar_dataset(archivo):
    import funciones as pd
    # Si se desea agregar un input se coloca:
    # archivo = input("Por favor, ingresa el nombre del archivo: ")
    extension = os.path.splitext(archivo)[1].lower()
# Cargar el archivo según su extensión
    if extension == '.csv':
        df = pd.read_csv(archivo)
        return(df)
    elif extension == '.xlsx':
        df = pd.read_excel(archivo)
        return(df)
    else:
        raise ValueError(f"Este formato no está soportado para esta función: {extension}")

# %%
def sustitucion_promedio(df):
    import funciones as pd
    cuantitativas = df.select_dtypes(include=['float64', 'int64', 'int'])
    cualitativas = df.select_dtypes(exclude=['float64', 'int64', 'int'])
    
    df_cuantitativas = cuantitativas.copy()
    
    # Sustituir impares numéricas con "99"
    for i, col in enumerate(df_cuantitativas.columns):
        if (i + 1) % 2 == 0: 
            df_cuantitativas[col] = df_cuantitativas[col].fillna(round(df_cuantitativas[col].mean(), 1))
        else:  
            df_cuantitativas[col] = df_cuantitativas[col].fillna(99)
    
    # Sustituir columnas que no sean de tipo numérico con "Este_es_un_valor_nulo"
    df_cualitativas = cualitativas.fillna("Este_es_un_valor_nulo")
    
    # Unimos el dataframe limpio con el dataframe cualitativo
    datos_sin_nulos = pd.concat([df_cuantitativas, df_cualitativas], axis=1)
    
    return datos_sin_nulos

# %%
# Reemplazamos valores nulos del dataframe con "mean"
data1 = df.fillna(method = 'ffill')
data1
# Out:
# /var/folders/lk/1s80q3g16rl6xn6yqybdsx3m0000gn/T/ipykernel_97198/352107749.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 = df.fillna(method = 'ffill')
#        Unnamed: 0                                               name  \
# 0               0               SEASIDE - Historic Antique Residence
# 1               1  BnB center near station with balcony and break...
# 2               2                         Etna-sea a panoramic villa
# 3               3                             Two steps from the sea
# 4               4                                    Villa Verdemare
# ...           ...                                                ...
# 57958       57958                       Appartamento Salgari Levante
# 57959       57959                       Appartamento Salgari Ponente
# 57960       57960                         Mini appartamento in Villa
# 57961       57961                    Tenuta Donna Vittoria - Piccola
# 57962       57962                               Casa Russo a Ficarra
#
#                                              description  \
# 0      WINEYARD WITH COLOURS OF THE SEASIDE.<br /><br...
# 1      Near the Central Station and the beginning of ...
# 2      Our country house, swathed in the greenery of ...
# 3      Very nice flat in front of the beach with a wo...
# 4      Wonderful villa that can easily accommodate up...
# ...                                                  ...
# 57958  Just a short walk from the beach, the holiday ...
# 57959  The holiday apartment Appartamento Salgari Pon...
# 57960  Located in Noto, the holiday apartment 'Mini a...
# 57961  The holiday apartment 'Tenuta Donna Vittoria -...
# 57962  The holiday home Casa Russo a Ficarra is locat...
#
#                                    neighborhood_overview     host_name  \
# 0                                                    NaN  Yumi Adriano
# 1      The neighborhood is in a residential area, cen...      Giuseppe
# 2      Contact with nature, relaxation, remarkable pa...        Serena
# 3      Contact with nature, relaxation, remarkable pa...       Gaspare
# 4      Contact with nature, relaxation, remarkable pa...       Gaspare
# ...                                                  ...           ...
# 57958  Palermo, among the most beautiful art cities i...        Holidu
# 57959  Palermo, among the most beautiful art cities i...        Holidu
# 57960  Palermo, among the most beautiful art cities i...        Holidu
# 57961  Palermo, among the most beautiful art cities i...        Holidu
# 57962  Palermo, among the most beautiful art cities i...        Holidu
#
#       host_since            host_location  \
# 0       13/05/09            Sicily, Italy
# 1       05/03/10         Agrigento, Italy
# 2       24/06/10  Piedimonte Etneo, Italy
# 3       05/08/10           Trapani, Italy
# 4       05/08/10           Trapani, Italy
# ...          ...                      ...
# 57958   10/01/24          Florence, Italy
# 57959   10/01/24          Florence, Italy
# 57960   05/05/23          Florence, Italy
# 57961   15/11/21          Florence, Italy
# 57962   12/07/22          Florence, Italy
#
#                                               host_about  host_response_time  \
# 0      Hi, this is Yumi, I  am a Japanese, I speak Ja...                 NaN
# 1      Di carattere tranquillo e dinamico, sposato, c...      within an hour
# 2                                                      .  within a few hours
# 3      Managing parents' houses in Trapani and in San...      within an hour
# 4      Managing parents' houses in Trapani and in San...      within an hour
# ...                                                  ...                 ...
# 57958  At Holidu, we're on a mission to make the host...      within an hour
# 57959  At Holidu, we're on a mission to make the host...      within an hour
# 57960  At Holidu, we're on a mission to make the host...      within an hour
# 57961  At Holidu, we're on a mission to make the host...      within an hour
# 57962  At Holidu, we're on a mission to make the host...      within an hour
#
#       host_response_rate  ... review_scores_rating review_scores_accuracy  \
# 0                    NaN  ...                 4.69                   4.66
# 1                   100%  ...                 4.80                   4.87
# 2                   100%  ...                 4.79                   4.82
# 3                   100%  ...                 4.68                   4.78
# 4                   100%  ...                 4.85                   4.82
# ...                  ...  ...                  ...                    ...
# 57958               100%  ...                 4.50                   4.50
# 57959               100%  ...                 4.50                   4.50
# 57960               100%  ...                 4.50                   4.50
# 57961               100%  ...                 4.50                   4.50
# 57962               100%  ...                 4.50                   4.50
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.86                   4.83
# 1                           4.89                   4.85
# 2                           4.83                   4.89
# 3                           4.57                   4.97
# 4                           4.69                   4.99
# ...                          ...                    ...
# 57958                       4.00                   5.00
# 57959                       4.00                   5.00
# 57960                       4.00                   5.00
# 57961                       4.00                   5.00
# 57962                       4.00                   5.00
#
#       review_scores_communication review_scores_communication.1  \
# 0                            4.72                          4.72
# 1                            4.81                          4.81
# 2                            4.81                          4.81
# 3                            4.94                          4.94
# 4                            4.92                          4.92
# ...                           ...                           ...
# 57958                        4.50                          4.50
# 57959                        4.50                          4.50
# 57960                        4.50                          4.50
# 57961                        4.50                          4.50
# 57962                        4.50                          4.50
#
#       review_scores_value  calculated_host_listings_count  \
# 0                    4.59                              10
# 1                    4.85                               3
# 2                    4.76                               5
# 3                    4.64                               2
# 4                    4.72                               2
# ...                   ...                             ...
# 57958                5.00                              68
# 57959                5.00                              68
# 57960                5.00                              56
# 57961                5.00                              59
# 57962                5.00                              40
#
#        calculated_host_listings_count_entire_homes reviews_per_month
# 0                                               10              0.18
# 1                                                0              2.48
# 2                                                5              0.90
# 3                                                2              0.49
# 4                                                2              0.46
# ...                                            ...               ...
# 57958                                           68              2.00
# 57959                                           68              2.00
# 57960                                           56              2.00
# 57961                                           59              2.00
# 57962                                           40              2.00
#
# [57963 rows x 51 columns]

# %%
# Reemplazamos valores nulos del dataframe con "bfill"
data1 = df.fillna(method = 'bfill')
data1
# Out:
# /var/folders/lk/1s80q3g16rl6xn6yqybdsx3m0000gn/T/ipykernel_97198/3803177468.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 = df.fillna(method = 'bfill')
#        Unnamed: 0                                               name  \
# 0               0               SEASIDE - Historic Antique Residence
# 1               1  BnB center near station with balcony and break...
# 2               2                         Etna-sea a panoramic villa
# 3               3                             Two steps from the sea
# 4               4                                    Villa Verdemare
# ...           ...                                                ...
# 57958       57958                       Appartamento Salgari Levante
# 57959       57959                       Appartamento Salgari Ponente
# 57960       57960                         Mini appartamento in Villa
# 57961       57961                    Tenuta Donna Vittoria - Piccola
# 57962       57962                               Casa Russo a Ficarra
#
#                                              description  \
# 0      WINEYARD WITH COLOURS OF THE SEASIDE.<br /><br...
# 1      Near the Central Station and the beginning of ...
# 2      Our country house, swathed in the greenery of ...
# 3      Very nice flat in front of the beach with a wo...
# 4      Wonderful villa that can easily accommodate up...
# ...                                                  ...
# 57958  Just a short walk from the beach, the holiday ...
# 57959  The holiday apartment Appartamento Salgari Pon...
# 57960  Located in Noto, the holiday apartment 'Mini a...
# 57961  The holiday apartment 'Tenuta Donna Vittoria -...
# 57962  The holiday home Casa Russo a Ficarra is locat...
#
#                                    neighborhood_overview     host_name  \
# 0      The neighborhood is in a residential area, cen...  Yumi Adriano
# 1      The neighborhood is in a residential area, cen...      Giuseppe
# 2      Contact with nature, relaxation, remarkable pa...        Serena
# 3      From a charm of a painting of Caravaggio or An...       Gaspare
# 4      From a charm of a painting of Caravaggio or An...       Gaspare
# ...                                                  ...           ...
# 57958                                                NaN        Holidu
# 57959                                                NaN        Holidu
# 57960                                                NaN        Holidu
# 57961                                                NaN        Holidu
# 57962                                                NaN        Holidu
#
#       host_since            host_location  \
# 0       13/05/09            Sicily, Italy
# 1       05/03/10         Agrigento, Italy
# 2       24/06/10  Piedimonte Etneo, Italy
# 3       05/08/10           Trapani, Italy
# 4       05/08/10           Trapani, Italy
# ...          ...                      ...
# 57958   10/01/24          Florence, Italy
# 57959   10/01/24          Florence, Italy
# 57960   05/05/23          Florence, Italy
# 57961   15/11/21          Florence, Italy
# 57962   12/07/22          Florence, Italy
#
#                                               host_about  host_response_time  \
# 0      Hi, this is Yumi, I  am a Japanese, I speak Ja...      within an hour
# 1      Di carattere tranquillo e dinamico, sposato, c...      within an hour
# 2                                                      .  within a few hours
# 3      Managing parents' houses in Trapani and in San...      within an hour
# 4      Managing parents' houses in Trapani and in San...      within an hour
# ...                                                  ...                 ...
# 57958  At Holidu, we're on a mission to make the host...      within an hour
# 57959  At Holidu, we're on a mission to make the host...      within an hour
# 57960  At Holidu, we're on a mission to make the host...      within an hour
# 57961  At Holidu, we're on a mission to make the host...      within an hour
# 57962  At Holidu, we're on a mission to make the host...      within an hour
#
#       host_response_rate  ... review_scores_rating review_scores_accuracy  \
# 0                   100%  ...                 4.69                   4.66
# 1                   100%  ...                 4.80                   4.87
# 2                   100%  ...                 4.79                   4.82
# 3                   100%  ...                 4.68                   4.78
# 4                   100%  ...                 4.85                   4.82
# ...                  ...  ...                  ...                    ...
# 57958               100%  ...                  NaN                    NaN
# 57959               100%  ...                  NaN                    NaN
# 57960               100%  ...                  NaN                    NaN
# 57961               100%  ...                  NaN                    NaN
# 57962               100%  ...                  NaN                    NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.86                   4.83
# 1                           4.89                   4.85
# 2                           4.83                   4.89
# 3                           4.57                   4.97
# 4                           4.69                   4.99
# ...                          ...                    ...
# 57958                        NaN                    NaN
# 57959                        NaN                    NaN
# 57960                        NaN                    NaN
# 57961                        NaN                    NaN
# 57962                        NaN                    NaN
#
#       review_scores_communication review_scores_communication.1  \
# 0                            4.72                          4.72
# 1                            4.81                          4.81
# 2                            4.81                          4.81
# 3                            4.94                          4.94
# 4                            4.92                          4.92
# ...                           ...                           ...
# 57958                         NaN                           NaN
# 57959                         NaN                           NaN
# 57960                         NaN                           NaN
# 57961                         NaN                           NaN
# 57962                         NaN                           NaN
#
#       review_scores_value  calculated_host_listings_count  \
# 0                    4.59                              10
# 1                    4.85                               3
# 2                    4.76                               5
# 3                    4.64                               2
# 4                    4.72                               2
# ...                   ...                             ...
# 57958                 NaN                              68
# 57959                 NaN                              68
# 57960                 NaN                              56
# 57961                 NaN                              59
# 57962                 NaN                              40
#
#        calculated_host_listings_count_entire_homes reviews_per_month
# 0                                               10              0.18
# 1                                                0              2.48
# 2                                                5              0.90
# 3                                                2              0.49
# 4                                                2              0.46
# ...                                            ...               ...
# 57958                                           68               NaN
# 57959                                           68               NaN
# 57960                                           56               NaN
# 57961                                           59               NaN
# 57962                                           40               NaN
#
# [57963 rows x 51 columns]

# %%
def cuenta_valores_nulos(data1):
    # valores nulos por columna
    valores_nulos_cols = data1.isnull().sum()
    # valores nulos por dataframe
    valores_nulos_df = data1.isnull().sum().sum()

    return("Valores nulos por columna", valores_nulos_cols,
           "Valores nulos por dataframe", valores_nulos_df)

# %%
# LLamamos a la función "cuenta_valores_nulos" y guardamos el retorno
cuenta_valores_nulos(data1)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                       0
#  name                                             0
#  description                                      0
#  neighborhood_overview                           29
#  host_name                                        0
#  host_since                                       0
#  host_location                                    0
#  host_about                                       0
#  host_response_time                               0
#  host_response_rate                               0
#  host_acceptance_rate                             0
#  host_is_superhost                                0
#  host_listings_count                              0
#  host_total_listings_count                        0
#  host_has_profile_pic                             0
#  host_identity_verified                           0
#  neighbourhood                                   29
#  latitude                                         0
#  longitude                                        0
#  property_type                                    0
#  room_type                                        0
#  accommodates                                     0
#  bathrooms                                        0
#  bedrooms                                         0
#  beds                                             0
#  amenities                                        0
#  price                                            0
#  minimum_nights                                   0
#  maximum_nights                                   0
#  minimum_minimum_nights                           0
#  maximum_maximum_nights                           0
#  has_availability                                 0
#  availability_30                                  0
#  availability_60                                  0
#  availability_90                                  0
#  availability_365                                 0
#  number_of_reviews                                0
#  number_of_reviews_ltm                            0
#  number_of_reviews_l30d                           0
#  first_review                                   108
#  last_review                                    108
#  review_scores_rating                           108
#  review_scores_accuracy                         108
#  review_scores_cleanliness                      108
#  review_scores_checkin                          108
#  review_scores_communication                    108
#  review_scores_communication.1                  108
#  review_scores_value                            108
#  calculated_host_listings_count                   0
#  calculated_host_listings_count_entire_homes      0
#  reviews_per_month                              108
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(1138))

# %%
data1.to_csv('Sicily_limpio.csv')
